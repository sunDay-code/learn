# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
#this is not required for the
#new version jupyter notebook
#but leave it here just in case
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open("src/ppl1.jpg")
# import os
# os.getcwd()

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (320, 320, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
pic_red.shape
# Out:
# (320, 320, 3)

# %%
#.     R, G, B

# red channel value 0-255 full pure red, 0 no red, pure black
plt.imshow(pic_red[:,:,0], cmap='gray') #cmap, color mapping

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
plt.imshow(pic_red[:,:,2], cmap='gray') #cmap, color mapping

# %%
# Green channel
pic_red[:,:,1] = 0

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (320, 320, 3)

# %%
pic_red[:,:,1].shape
# Out:
# (320, 320)
