# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('src/ppl1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
wrongImg=cv2.imread("no/path/here.jpg") # no err

# %%
type(wrongImg)
# Out:
# NoneType

# %%
img.shape
# Out:
# (320, 320, 3)

# %%
plt.imshow(img)

# %%
# matplotlib --> RGB red, green, blue
# opencv --> blue, green, red

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #conver img to RGB

# %%
plt.imshow(fix_img)

# %%
# read as fresh gray image
img_gray = cv2.imread('src/ppl1.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (320, 320)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (320, 320, 3)

# %%
new_img = cv2.resize(fix_img, (160, 200))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.2
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (160, 64, 3)

# %%
new_img = cv2.flip(fix_img,-1)

# %%
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite("src/newppl1.jpg",new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8)) # figsize is just how big in notebook
ax = fig.add_subplot(111)
ax.imshow(fix_img)
