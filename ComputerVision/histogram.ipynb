# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ppl = cv2.imread('assets/ppl1.jpg')
show_ppl = cv2.cvtColor(ppl,cv2.COLOR_BGR2RGB)

# %%
scene = cv2.imread('assets/scene1.jpg')
show_scene = cv2.cvtColor(scene,cv2.COLOR_BGR2RGB)

# %%
scene2 = cv2.imread('assets/scene2.jpg')
show_scene2 = cv2.cvtColor(scene2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(ppl)

# %%
hist_values = cv2.calcHist([ppl],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
hist_values.shape
# Out:
# (256, 1)

# %%
plt.plot(hist_values)

# %%
img = ppl

# %%
color = ('b','g','r')

for i, col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color=col)
    plt.xlim([210,256])
    plt.ylim([0,2000])
plt.title('histogram for ppl')
# Out:
# Text(0.5, 1.0, 'histogram for ppl')
